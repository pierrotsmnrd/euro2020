# %% [markdown]
# ----

# %%
from datetime import datetime

# %%
import requests
import json
import os
from pprint import pprint

# %%
def download_url(url):
    headers = {
    "accept":"application/json",
    "content-type":"application/json",
    "x-api-key":"3d996743-0e66-4c37-b4c6-20f309040d87",
    "if-none-match":"0cfeec2f23a3cff3faff5f5d08f860e42",
    "user-agent":"NTC-ios/7.9.0",
    "accept-language":"fr-fr",
    }

    resp = requests.get(url,headers=headers)
    return resp.json()

# %%
def get_all_matches_for_team(team_id):
    url = f"https://match.uefa.com/v2/matches?language=FR&offset=0&limit=20&style=FULL&teamId={team_id}"
    all_matches = download_url(url)


    passed_matches = []
    upcoming_matches = []
    for m in all_matches:

        is_passed = datetime.strptime(m['kickOffTime']['date'], '%Y-%m-%d')  < datetime.now()

        new_match = {
            'id':m['id'],
            'away_team':m['awayTeam']['countryCode'],
            'home_team':m['homeTeam']['countryCode'],
            'competition_code':m['competition']['code'],
            'competition_id':m['competition']['id'],
            'competition_name':m['competition']['metaData']['name'],
            'competition_times':m['kickOffTime'],
        }
        if is_passed:
            passed_matches.append(new_match)
        else:
            upcoming_matches.append(new_match)
            
    return (passed_matches, upcoming_matches)

# %%
def download_events_for_match(match_id):
    url = f'''https://editorial.uefa.com/api/cachedsearch/build?language=FR
    &aggregator=lightnodejson
    &limit=20
    &offset=0
    &type=liveblog
    &sorting=-attributes.firstPublicationDate
    &param.attributes.language=fr
    &param.attributes.footballEntities.match.matchId={match_id}
    &param%5Battributes%5D%5BhideFromApp%21%5D=true'''.replace("\n","").replace(' ', '')

    #print(url)
    match_data = download_url(url)

    match_editorial_id = match_data['result'][0]['nodeData']['id']
    
    # Next step : rebuild all events
    #events_idxed = {}
    events = []
    last_id = None
    while True:

        if last_id is not None:
            url = f"https://editorial.uefa.com/api/liveblogs/{match_editorial_id}/posts?language=FR&aggregator=lightliveblogjson&limit=40&from={last_id}"
        else:
            url = f"https://editorial.uefa.com/api/liveblogs/{match_editorial_id}/posts?language=FR&aggregator=lightliveblogjson&limit=40"
        #print(url)
        match_data = download_url(url)

        for item in match_data['result']:
            if item['attributes']['liveblogPostData']['lbPostType'] == 'MATCH_EVENT':
                #print(item['id'])
                #print(item['attributes']['liveblogPostData']['lbPostTimestamp'])

                event_type = item['attributes']['liveblogPostData']['lbPostEvent']['eventType']
                event_translated =  item['attributes']['liveblogPostData']['lbPostEvent']['eventTranslation']

                #if event_type not in events_idxed:
                #    events_idxed[event_type] = []
                #events_idxed[event_type].append(event_translated)

                events.insert(0, {'id':item['id'], 
                                  'timestamp':item['attributes']['liveblogPostData']['lbPostTimestamp'],
                                  'event_type':event_type,
                                  'event_translated':event_translated,
                                  'liveblog_raw':item['attributes']['liveblogPostData']
                                 }) 
            last_id = item['id']
        if match_data['count'] < 40:
            print(f" Expected 40 items, go {match_data['count']}. Break")
            break
       
    return events

# %%
team_id = 43 # France
#team_id = 66 # Italy
#team_id = 127 # Sweden
(passed_matches, upcoming_matches) = get_all_matches_for_team(team_id)

# %%
for i in range(len(passed_matches)):
    print(passed_matches[i]['id'])
    print(passed_matches[i])
    print()
# Out:
# 2032159
# {'id': '2032159', 'away_team': 'ARM', 'home_team': 'SWE', 'competition_code': 'A Int.', 'competition_id': '19', 'competition_name': 'Friendly Matches', 'competition_times': {'date': '2021-06-05', 'dateTime': '2021-06-05T18:45:00Z', 'utcOffsetInHours': 2}}
#
# 2032177
# {'id': '2032177', 'away_team': 'FIN', 'home_team': 'SWE', 'competition_code': 'A Int.', 'competition_id': '19', 'competition_name': 'Friendly Matches', 'competition_times': {'date': '2021-05-29', 'dateTime': '2021-05-29T16:00:00Z', 'utcOffsetInHours': 2}}
#
# 2031953
# {'id': '2031953', 'away_team': 'EST', 'home_team': 'SWE', 'competition_code': 'A Int.', 'competition_id': '19', 'competition_name': 'Friendly Matches', 'competition_times': {'date': '2021-03-31', 'dateTime': '2021-03-31T15:45:00Z', 'utcOffsetInHours': 2}}
#
# 2030810
# {'id': '2030810', 'away_team': 'SWE', 'home_team': 'KOS', 'competition_code': 'WC', 'competition_id': '17', 'competition_name': 'FIFA World Cup', 'competition_times': {'date': '2021-03-28', 'dateTime': '2021-03-28T18:45:00Z', 'utcOffsetInHours': 2}}
#
# 2030778
# {'id': '2030778', 'away_team': 'GEO', 'home_team': 'SWE', 'competition_code': 'WC', 'competition_id': '17', 'competition_name': 'FIFA World Cup', 'competition_times': {'date': '2021-03-25', 'dateTime': '2021-03-25T19:45:00Z', 'utcOffsetInHours': 1}}
#
# 2030108
# {'id': '2030108', 'away_team': 'SWE', 'home_team': 'FRA', 'competition_code': 'UNL', 'competition_id': '2014', 'competition_name': 'UEFA Nations League', 'competition_times': {'date': '2020-11-17', 'dateTime': '2020-11-17T19:45:00Z', 'utcOffsetInHours': 1}}
#
# 2030081
# {'id': '2030081', 'away_team': 'CRO', 'home_team': 'SWE', 'competition_code': 'UNL', 'competition_id': '2014', 'competition_name': 'UEFA Nations League', 'competition_times': {'date': '2020-11-14', 'dateTime': '2020-11-14T19:45:00Z', 'utcOffsetInHours': 1}}
#
# 2030230
# {'id': '2030230', 'away_team': 'SWE', 'home_team': 'DEN', 'competition_code': 'A Int.', 'competition_id': '19', 'competition_name': 'Friendly Matches', 'competition_times': {'date': '2020-11-11', 'dateTime': '2020-11-11T18:30:00Z', 'utcOffsetInHours': 1}}
#
# 2030061
# {'id': '2030061', 'away_team': 'SWE', 'home_team': 'POR', 'competition_code': 'UNL', 'competition_id': '2014', 'competition_name': 'UEFA Nations League', 'competition_times': {'date': '2020-10-14', 'dateTime': '2020-10-14T18:45:00Z', 'utcOffsetInHours': 1}}
#
# 2030035
# {'id': '2030035', 'away_team': 'SWE', 'home_team': 'CRO', 'competition_code': 'UNL', 'competition_id': '2014', 'competition_name': 'UEFA Nations League', 'competition_times': {'date': '2020-10-11', 'dateTime': '2020-10-11T16:00:00Z', 'utcOffsetInHours': 2}}
#
# 2029156
# {'id': '2029156', 'away_team': 'SWE', 'home_team': 'RUS', 'competition_code': 'A Int.', 'competition_id': '19', 'competition_name': 'Friendly Matches', 'competition_times': {'date': '2020-10-08', 'dateTime': '2020-10-08T16:15:00Z', 'utcOffsetInHours': 3}}

# %%
events_translation = { "1":"red_card",
                        "2":"red_card",
                        #"3":"goal", # may contain "penalty"
                        "4":"player_switch", #changement
                        "5":"missed_penalty", 
                        "6":"stopped_shot",
                        "7":"out_of_frame_shot",
                        "8":"framed_shot",
                        "9":"offside", 
                        "10":"corner_shot",
                        "11":"foul",  # may contain penalty 
                        "12":"assist", # passe décisive
                        "13":"phase_start", 
                        "14":"phase_end",
                        "19":"additional_time",
                        "30":"free_kick",
                        "32":"stop", # arrêt par le gardien
                        "80":"corner_concealed"
                     }

os.makedirs(f"data/matches/", exist_ok=True)

last_matches_ids = [m['id'] for m in passed_matches]

for match_id in last_matches_ids: 
    print(match_id)
    
    fpath = f"data/matches/{match_id}_events.json"
    if os.path.isfile(fpath) and False:
        print("loading cached data")
        with open(fpath, "r") as f:
            events = json.loads(f.read())
            
    else:
        print("downloading data")        
        events = download_events_for_match(match_id)
        with open(fpath, "w") as f:
            f.write(json.dumps(events))


    for e in events:

        #if e['event_type'] in events_translation:
        #    continue

        if 'penalty' not in e['event_translated']:
            continue
        
        print(e['event_type'], e['event_translated'])

        print("Mi-Temps #%s"%(e['liveblog_raw']['lbPostEvent']['eventPhase'])  , 
              "%s:%s"%(e['liveblog_raw']['lbPostEvent']['eventMinute'], e['liveblog_raw']['lbPostEvent']['eventSecond'])      )
        try:
            print(e['liveblog_raw']['lbPostEvent']['idPlayer'], " -> ", e['liveblog_raw']['lbPostEvent']['idPlayerTo'] )
            print(e['liveblog_raw']['lbPostEvent']['idTeam'], " -> ",   e['liveblog_raw']['lbPostEvent']['idTeamTo']  )
            print(e['liveblog_raw']['lbPostEvent']['namePlayer'] , " -> ",  e['liveblog_raw']['lbPostEvent']['namePlayerTo']  )
        except:
            try:
                print(e['liveblog_raw']['lbPostEvent']['idPlayer']  )
                print(e['liveblog_raw']['lbPostEvent']['idTeam']  )
                print(e['liveblog_raw']['lbPostEvent']['namePlayer']  )
            except:
                pass

        #if e['event_type'] in ("19"):
        #    pprint(e)
    print("----")
# Out:
# 2032240
# downloading data
# https://editorial.uefa.com/api/cachedsearch/build?language=FR&aggregator=lightnodejson&limit=20&offset=0&type=liveblog&sorting=-attributes.firstPublicationDate&param.attributes.language=fr&param.attributes.footballEntities.match.matchId=2032240&param%5Battributes%5D%5BhideFromApp%21%5D=true
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-b78e90d395b1> in <module>
#      39
#      40
# ---> 41     for e in events:
#      42
#      43         #if e['event_type'] in events_translation:
#
# TypeError: 'NoneType' object is not iterable

# %% [markdown]
# ### ----
# ## Below is raw research

# %% [markdown]
# Click sur France =>
#
#
#
# # This url allows to build the second one.
# # it also gives extra perks like the referees and stuff
#
#
# https://editorial.uefa.com/api/cachedsearch/build?language=FR&aggregator=lightnodejson&limit=10
# &offset=0
# &type=videostory
# &sorting=-attributes.firstPublicationDate
# &param.attributes.language=fr
# &param.attributes.main.kind=Highlights
# &param.attributes.main.kind=Medium+Highlights
# &param.attributes.footballEntities.match.matchId=2032240
# &param.attributes.footballEntities.match.matchId=2030818
# &param.attributes.footballEntities.match.matchId=2030791
# &param.attributes.footballEntities.match.matchId=2030762
# &param.attributes.footballEntities.match.matchId=2030108
# &param.attributes.footballEntities.match.matchId=2030080
# &param.attributes.footballEntities.match.matchId=2029167
# &param.attributes.footballEntities.match.matchId=2030063
# &param.attributes.footballEntities.match.matchId=2030032
# &param.attributes.footballEntities.match.matchId=2029150
# &param%5Battributes%5D%5BhideFromApp%21%5D=true
# # this url doesn't give the detailled flow of an event
#
#
# https://editorial.uefa.com/api/cachedsearch/build?language=FR&aggregator=lightnodejson&limit=20
# &offset=0
# &type=article
# &type=videostory
# &sorting=-attributes.firstPublicationDate
# &param.attributes.language=fr
# &param.attributes.footballEntities.team.teamId=43
# &param%5Battributes%5D%5BhideFromApp%21%5D=true

# %%
lineup = download_url("https://match.uefa.com/v3/matches/2032240/lineups?language=FR")

test = download_url("https://match.uefa.com/v2/matches/2032240/events?language=FR&filter=LINEUP&offset=0&limit=50")

# %%
pprint(test)
# Out:
# [{'fieldPosition': {},
#   'id': 'b88eb0d0b0914a33856c15842db71385',
#   'matchId': '2032240',
#   'phase': 'SECOND_HALF',
#   'primaryActor': {'person': {'age': '28',
#                               'birthDate': '1992-08-08',
#                               'detailedFieldPosition': 'UNKNOWN',
#                               'fieldPosition': 'FORWARD',
#                               'id': '250130512',
#                               'imageUrl': 'https://img.uefa.com/imgml/TP/players/19/2022/324x324/250130512.jpg',
#                               'internationalName': 'Kieffer Moore',
#                               'translations': {'fieldPosition': {'AZ': 'Forward',
#                                                                  'DA': 'Forward',
#                                                                  'DE': 'Stürmer',
#                                                                  'EN': 'Forward',
#                                                                  'ES': 'Delantero',
#                                                                  'FR': 'Attaquant',
#                                                                  'HU': 'Forward',
#                                                                  'IT': 'Attaccante',
#                                                                  'JA': 'FW',
#                                                                  'NL': 'Forward',
#                                                                  'PT': 'Avançado',
#                                                                  'RO': 'Forward',
#                                                                  'RU': 'Нападающий',
#                                                                  'ZH': '前锋'},
#                                                'firstName': {'AZ': 'Kieffer',
#                                                              'DA': 'Kieffer',
#                                                              'DE': 'Kieffer',
#                                                              'EN': 'Kieffer',
#                                                              'ES': 'Kieffer',
#                                                              'FR': 'Kieffer',
#                                                              'HU': 'Kieffer',
#                                                              'IT': 'Kieffer',
#                                                              'JA': 'Kieffer',
#                                                              'NL': 'Kieffer',
#                                                              'PT': 'Kieffer',
#                                                              'RO': 'Kieffer',
#                                                              'RU': 'Киффер',
#                                                              'ZH': 'Kieffer'},
#                                                'lastName': {'AZ': 'Moore',
#                                                             'DA': 'Moore',
#                                                             'DE': 'Moore',
#                                                             'EN': 'Moore',
#                                                             'ES': 'Moore',
#                                                             'FR': 'Moore',
#                                                             'HU': 'Moore',
#                                                             'IT': 'Moore',
#                                                             'JA': 'Moore',
#                                                             'NL': 'Moore',
#                                                             'PT': 'Moore',
#                                                             'RO': 'Moore',
#                                                             'RU': 'Мур',
#                                                             'ZH': 'Moore'},
#                                                'name': {'AZ': 'Kieffer Moore',
#                                                         'DA': 'Kieffer Moore',
#                                                         'DE': 'Kieffer Moore',
#                                                         'EN': 'Kieffer Moore',
#                                                         'ES': 'Kieffer Moore',
#                                                         'FR': 'Kieffer Moore',
#                                                         'HU': 'Kieffer Moore',
#                                                         'IT': 'Kieffer Moore',
#                                                         'JA': 'Kieffer Moore',
#                                                         'NL': 'Kieffer Moore',
#                                                         'PT': 'Kieffer Moore',
#                                                         'RO': 'Kieffer Moore',
#                                                         'RU': 'Киффер Мур',
#                                                         'ZH': 'Kieffer Moore'},
#                                                'shortName': {'AZ': 'Moore',
#                                                              'DA': 'Moore',
#                                                              'DE': 'Moore',
#                                                              'EN': 'Moore',
#                                                              'ES': 'Moore',
#                                                              'FR': 'Moore',
#                                                              'HU': 'Moore',
#                                                              'IT': 'Moore',
#                                                              'JA': 'Moore',
#                                                              'NL': 'Moore',
#                                                              'PT': 'Moore',
#                                                              'RO': 'Moore',
#                                                              'RU': 'Мур',
#                                                              'ZH': 'Moore'}}},
#                    'team': {'associationLogoUrl': 'https://img.uefa.com/imgml/uefacom/elements/logos/ma/WAL.svg',
#                             'bigLogoUrl': 'https://www.uefa.com/imgml/flags/700x700/WAL.png',
#                             'countryCode': 'WAL',
#                             'id': '144',
#                             'idProvider': 'FAME',
#                             'internationalName': 'Wales',
#                             'isPlaceHolder': False,
#                             'logoUrl': 'https://www.uefa.com/imgml/flags/70x70/WAL.png',
#                             'mediumLogoUrl': 'https://www.uefa.com/imgml/flags/240x240/WAL.png',
#                             'teamCode': 'WAL',
#                             'teamTypeDetail': 'NATIONAL_MEN_TEAM_A',
#                             'translations': {'countryName': {'AZ': 'Wales',
#                                                              'DA': 'Wales',
#                                                              'DE': 'Wales',
#                                                              'EN': 'Wales',
#                                                              'ES': 'Gales',
#                                                              'FR': 'Pays de '
#                                                                    'Galles',
#                                                              'HU': 'Wales',
#                                                              'IT': 'Galles',
#                                                              'JA': 'ウェールズ',
#                                                              'NL': 'Wales',
#                                                              'PT': 'País de '
#                                                                    'Gales',
#                                                              'RO': 'Wales',
#                                                              'RU': 'Уэльс',
#                                                              'ZH': '威尔士'},
#                                              'displayName': {'AZ': 'Uels',
#                                                              'DA': 'Wales',
#                                                              'DE': 'Wales',
#                                                              'EN': 'Wales',
#                                                              'ES': 'Gales',
#                                                              'FR': 'Pays de '
#                                                                    'Galles',
#                                                              'HU': 'Wales',
#                                                              'IT': 'Galles',
#                                                              'JA': 'ウェールズ',
#                                                              'NL': 'Wales',
#                                                              'PT': 'País de '
#                                                                    'Gales',
#                                                              'RO': 'Țara '
#                                                                    'Galilor',
#                                                              'RU': 'Уэльс',
#                                                              'ZH': '威尔士'},
#                                              'displayOfficialName': {'AZ': 'Uels',
#                                                                      'DA': 'Wales',
#                                                                      'DE': 'Wales',
#                                                                      'EN': 'Wales',
#                                                                      'ES': 'Gales',
#                                                                      'FR': 'Pays '
#                                                                            'de '
#                                                                            'Galles',
#                                                                      'HU': 'Wales',
#                                                                      'IT': 'Galles',
#                                                                      'JA': 'ウェールズ',
#                                                                      'NL': 'Wales',
#                                                                      'PT': 'País '
#                                                                            'de '
#                                                                            'Gales',
#                                                                      'RO': 'Țara '
#                                                                            'Galilor',
#                                                                      'RU': 'Уэльс',
#                                                                      'ZH': '威尔士'},
#                                              'displayTeamCode': {'AZ': 'WAL',
#                                                                  'DA': 'WAL',
#                                                                  'DE': 'WAL',
#                                                                  'EN': 'WAL',
#                                                                  'ES': 'WAL',
#                                                                  'FR': 'WAL',
#                                                                  'HU': 'WAL',
#                                                                  'IT': 'WAL',
#                                                                  'JA': 'WAL',
#                                                                  'NL': 'WAL',
#                                                                  'PT': 'WAL',
#                                                                  'RO': 'WAL',
#                                                                  'RU': 'WAL',
#                                                                  'ZH': 'WAL'}},
#                             'typeIsNational': True,
#                             'typeTeam': 'NATIONAL'},
#                    'type': 'PLAYER'},
#   'time': {'injuryMinute': 2, 'minute': 90, 'second': 53},
#   'timestamp': '2021-06-02T20:55:19.568Z',
#   'type': 'YELLOW_CARD'},
#  {'fieldPosition': {},
#   'id': '7825313bd8dd4c798e409322970632a3',
#   'matchId': '2032240',
#   'phase': 'SECOND_HALF',
#   'primaryActor': {'person': {'age': '30',
#                               'birthDate': '1991-03-21',
#                               'countryCode': 'FRA',
#                               'detailedFieldPosition': 'STRIKER',
#                               'fieldPosition': 'FORWARD',
#                               'height': 176,
#                               'id': '250019498',
#                               'imageUrl': 'https://img.uefa.com/imgml/TP/players/19/2022/324x324/250019498.jpg',
#                               'internationalName': 'Antoine Griezmann',
#                               'translations': {'countryName': {'AZ': 'France',
#                                                                'DA': 'France',
#                                                                'DE': 'Frankreich',
#                                                                'EN': 'France',
#                                                                'ES': 'Francia',
#                                                                'FR': 'France',
#                                                                'HU': 'France',
#                                                                'IT': 'Francia',
#                                                                'JA': 'フランス',
#                                                                'NL': 'France',
#                                                                'PT': 'França',
#                                                                'RO': 'France',
#                                                                'RU': 'Франция',
#                                                                'ZH': '法国'},
#                                                'fieldPosition': {'AZ': 'Forward',
#                                                                  'DA': 'Forward',
#                                                                  'DE': 'Stürmer',
#                                                                  'EN': 'Forward',
#                                                                  'ES': 'Delantero',
#                                                                  'FR': 'Attaquant',
#                                                                  'HU': 'Forward',
#                                                                  'IT': 'Attaccante',
#                                                                  'JA': 'FW',
#                                                                  'NL': 'Forward',
#                                                                  'PT': 'Avançado',
#                                                                  'RO': 'Forward',
#                                                                  'RU': 'Нападающий',
#                                                                  'ZH': '前锋'},
#                                                'firstName': {'AZ': 'Antoine',
#                                                              'DA': 'Antoine',
#                                                              'DE': 'Antoine',
#                                                              'EN': 'Antoine',
#                                                              'ES': 'Antoine',
#                                                              'FR': 'Antoine',
#                                                              'HU': 'Antoine',
#                                                              'IT': 'Antoine',
#                                                              'JA': 'アントワーヌ',
#                                                              'NL': 'Antoine',
#                                                              'PT': 'Antoine',
#                                                              'RO': 'Antoine',
#                                                              'RU': 'Антуан',
#                                                              'ZH': '安东尼'},
#                                                'lastName': {'AZ': 'Griezmann',
#                                                             'DA': 'Griezmann',
#                                                             'DE': 'Griezmann',
#                                                             'EN': 'Griezmann',
#                                                             'ES': 'Griezmann',
#                                                             'FR': 'Griezmann',
#                                                             'HU': 'Griezmann',
#                                                             'IT': 'Griezmann',
#                                                             'JA': 'グリーズマン',
#                                                             'NL': 'Griezmann',
#                                                             'PT': 'Griezmann',
#                                                             'RO': 'Griezmann',
#                                                             'RU': 'Гризманн',
#                                                             'ZH': '格列兹曼'},
#                                                'name': {'AZ': 'Antoine '
#                                                               'Griezmann',
#                                                         'DA': 'Antoine '
#                                                               'Griezmann',
#                                                         'DE': 'Antoine '
#                                                               'Griezmann',
#                                                         'EN': 'Antoine '
#                                                               'Griezmann',
#                                                         'ES': 'Antoine '
#                                                               'Griezmann',
#                                                         'FR': 'Antoine '
#                                                               'Griezmann',
#                                                         'HU': 'Antoine '
#                                                               'Griezmann',
#                                                         'IT': 'Antoine '
#                                                               'Griezmann',
#                                                         'JA': 'アントワーヌ・グリーズマン',
#                                                         'NL': 'Antoine '
#                                                               'Griezmann',
#                                                         'PT': 'Antoine '
#                                                               'Griezmann',
#                                                         'RO': 'Antoine '
#                                                               'Griezmann',
#                                                         'RU': 'Антуан Гризманн',
#                                                         'ZH': '安东尼·格列兹曼'},
#                                                'shortName': {'AZ': 'Griezmann',
#                                                              'DA': 'Griezmann',
#                                                              'DE': 'Griezmann',
#                                                              'EN': 'Griezmann',
#                                                              'ES': 'Griezmann',
#                                                              'FR': 'Griezmann',
#                                                              'HU': 'Griezmann',
#                                                              'IT': 'Griezmann',
#                                                              'JA': 'グリーズマン',
#                                                              'NL': 'Griezmann',
#                                                              'PT': 'Griezmann',
#                                                              'RO': 'Griezmann',
#                                                              'RU': 'Гризманн',
#                                                              'ZH': '格列兹曼'}},
#                               'weight': 67},
#                    'team': {'associationLogoUrl': 'https://img.uefa.com/imgml/uefacom/elements/logos/ma/FRA.svg',
#                             'bigLogoUrl': 'https://www.uefa.com/imgml/flags/700x700/FRA.png',
#                             'countryCode': 'FRA',
#                             'id': '43',
#                             'idProvider': 'FAME',
#                             'internationalName': 'France',
#                             'isPlaceHolder': False,
#                             'logoUrl': 'https://www.uefa.com/imgml/flags/70x70/FRA.png',
#                             'mediumLogoUrl': 'https://www.uefa.com/imgml/flags/240x240/FRA.png',
#                             'teamCode': 'FRA',
#                             'teamTypeDetail': 'NATIONAL_MEN_TEAM_A',
#                             'translations': {'countryName': {'AZ': 'France',
#                                                              'DA': 'France',
#                                                              'DE': 'Frankreich',
#                                                              'EN': 'France',
#                                                              'ES': 'Francia',
#                                                              'FR': 'France',
#                                                              'HU': 'France',
#                                                              'IT': 'Francia',
#                                                              'JA': 'フランス',
#                                                              'NL': 'France',
#                                                              'PT': 'França',
#                                                              'RO': 'France',
#                                                              'RU': 'Франция',
#                                                              'ZH': '法国'},
#                                              'displayName': {'AZ': 'Fransa',
#                                                              'DA': 'Frankrig',
#                                                              'DE': 'Frankreich',
#                                                              'EN': 'France',
#                                                              'ES': 'Francia',
#                                                              'FR': 'France',
#                                                              'HU': 'Franciaország',
#                                                              'IT': 'Francia',
#                                                              'JA': 'フランス',
#                                                              'NL': 'Frankrijk',
#                                                              'PT': 'França',
#                                                              'RO': 'Franța',
#                                                              'RU': 'Франция',
#                                                              'ZH': '法国'},
#                                              'displayOfficialName': {'AZ': 'Fransa',
#                                                                      'DA': 'Frankrig',
#                                                                      'DE': 'Frankreich',
#                                                                      'EN': 'France',
#                                                                      'ES': 'Francia',
#                                                                      'FR': 'France',
#                                                                      'HU': 'Franciaország',
#                                                                      'IT': 'Francia',
#                                                                      'JA': 'フランス',
#                                                                      'NL': 'Frankrijk',
#                                                                      'PT': 'França',
#                                                                      'RO': 'Franța',
#                                                                      'RU': 'Франция',
#                                                                      'ZH': '法国'},
#                                              'displayTeamCode': {'AZ': 'FRA',
#                                                                  'DA': 'FRA',
#                                                                  'DE': 'FRA',
#                                                                  'EN': 'FRA',
#                                                                  'ES': 'FRA',
#                                                                  'FR': 'FRA',
#                                                                  'HU': 'FRA',
#                                                                  'IT': 'FRA',
#                                                                  'JA': 'FRA',
#                                                                  'NL': 'FRA',
#                                                                  'PT': 'FRA',
#                                                                  'RO': 'FRA',
#                                                                  'RU': 'FRA',
#                                                                  'ZH': 'FRA'}},
#                             'typeIsNational': True,
#                             'typeTeam': 'NATIONAL'},
#                    'type': 'PLAYER'},
#   'secondaryActor': {'person': {'age': '30',
#                                 'birthDate': '1990-08-12',
#                                 'countryCode': 'FRA',
#                                 'detailedFieldPosition': 'STRIKER',
#                                 'fieldPosition': 'FORWARD',
#                                 'height': 170,
#                                 'id': '250025970',
#                                 'imageUrl': 'https://img.uefa.com/imgml/TP/players/19/2022/324x324/250025970.jpg',
#                                 'internationalName': 'Wissam Ben Yedder',
#                                 'translations': {'countryName': {'AZ': 'France',
#                                                                  'DA': 'France',
#                                                                  'DE': 'Frankreich',
#                                                                  'EN': 'France',
#                                                                  'ES': 'Francia',
#                                                                  'FR': 'France',
#                                                                  'HU': 'France',
#                                                                  'IT': 'Francia',
#                                                                  'JA': 'フランス',
#                                                                  'NL': 'France',
#                                                                  'PT': 'França',
#                                                                  'RO': 'France',
#                                                                  'RU': 'Франция',
#                                                                  'ZH': '法国'},
#                                                  'fieldPosition': {'AZ': 'Forward',
#                                                                    'DA': 'Forward',
#                                                                    'DE': 'Stürmer',
#                                                                    'EN': 'Forward',
#                                                                    'ES': 'Delantero',
#                                                                    'FR': 'Attaquant',
#                                                                    'HU': 'Forward',
#                                                                    'IT': 'Attaccante',
#                                                                    'JA': 'FW',
#                                                                    'NL': 'Forward',
#                                                                    'PT': 'Avançado',
#                                                                    'RO': 'Forward',
#                                                                    'RU': 'Нападающий',
#                                                                    'ZH': '前锋'},
#                                                  'firstName': {'AZ': 'Wissam',
#                                                                'DA': 'Wissam',
#                                                                'DE': 'Wissam',
#                                                                'EN': 'Wissam',
#                                                                'ES': 'Wissam',
#                                                                'FR': 'Wissam',
#                                                                'HU': 'Wissam',
#                                                                'IT': 'Wissam',
#                                                                'JA': 'ビサム',
#                                                                'NL': 'Wissam',
#                                                                'PT': 'Wissam',
#                                                                'RO': 'Wissam',
#                                                                'RU': 'Виссам',
#                                                                'ZH': '本'},
#                                                  'lastName': {'AZ': 'Ben '
#                                                                     'Yedder',
#                                                               'DA': 'Ben '
#                                                                     'Yedder',
#                                                               'DE': 'Ben '
#                                                                     'Yedder',
#                                                               'EN': 'Ben '
#                                                                     'Yedder',
#                                                               'ES': 'Ben '
#                                                                     'Yedder',
#                                                               'FR': 'Ben '
#                                                                     'Yedder',
#                                                               'HU': 'Ben '
#                                                                     'Yedder',
#                                                               'IT': 'Ben '
#                                                                     'Yedder',
#                                                               'JA': 'ベン・イェデル',
#                                                               'NL': 'Ben '
#                                                                     'Yedder',
#                                                               'PT': 'Ben '
#                                                                     'Yedder',
#                                                               'RO': 'Ben '
#                                                                     'Yedder',
#                                                               'RU': 'Бен-Йеддер',
#                                                               'ZH': '耶德尔'},
#                                                  'name': {'AZ': 'Wissam Ben '
#                                                                 'Yedder',
#                                                           'DA': 'Wissam Ben '
#                                                                 'Yedder',
#                                                           'DE': 'Wissam Ben '
#                                                                 'Yedder',
#                                                           'EN': 'Wissam Ben '
#                                                                 'Yedder',
#                                                           'ES': 'Wissam Ben '
#                                                                 'Yedder',
#                                                           'FR': 'Wissam Ben '
#                                                                 'Yedder',
#                                                           'HU': 'Wissam Ben '
#                                                                 'Yedder',
#                                                           'IT': 'Wissam Ben '
#                                                                 'Yedder',
#                                                           'JA': 'ビサム・ベン・イェデル',
#                                                           'NL': 'Wissam Ben '
#                                                                 'Yedder',
#                                                           'PT': 'Wissam Ben '
#                                                                 'Yedder',
#                                                           'RO': 'Wissam Ben '
#                                                                 'Yedder',
#                                                           'RU': 'Виссам '
#                                                                 'Бен-Йеддер',
#                                                           'ZH': '本·耶德尔'},
#                                                  'shortName': {'AZ': 'Ben '
#                                                                      'Yedder',
#                                                                'DA': 'Ben '
#                                                                      'Yedder',
#                                                                'DE': 'Ben '
#                                                                      'Yedder',
#                                                                'EN': 'Ben '
#                                                                      'Yedder',
#                                                                'ES': 'Ben '
#                                                                      'Yedder',
#                                                                'FR': 'Ben '
#                                                                      'Yedder',
#                                                                'HU': 'Ben '
#                                                                      'Yedder',
#                                                                'IT': 'Ben '
#                                                                      'Yedder',
#                                                                'JA': 'ベン・イェデル',
#                                                                'NL': 'Ben '
#                                                                      'Yedder',
#                                                                'PT': 'Ben '
#                                                                      'Yedder',
#                                                                'RO': 'Ben '
#                                                                      'Yedder',
#                                                                'RU': 'Бен-Йеддер',
#                                                                'ZH': '耶德尔'}},
#                                 'weight': 68},
#                      'team': {'associationLogoUrl': 'https://img.uefa.com/imgml/uefacom/elements/logos/ma/FRA.svg',
#                               'bigLogoUrl': 'https://www.uefa.com/imgml/flags/700x700/FRA.png',
#                               'countryCode': 'FRA',
#                               'id': '43',
#                               'idProvider': 'FAME',
#                               'internationalName': 'France',
#                               'isPlaceHolder': False,
#                               'logoUrl': 'https://www.uefa.com/imgml/flags/70x70/FRA.png',
#                               'mediumLogoUrl': 'https://www.uefa.com/imgml/flags/240x240/FRA.png',
#                               'teamCode': 'FRA',
#                               'teamTypeDetail': 'NATIONAL_MEN_TEAM_A',
#                               'translations': {'countryName': {'AZ': 'France',
#                                                                'DA': 'France',
#                                                                'DE': 'Frankreich',
#                                                                'EN': 'France',
#                                                                'ES': 'Francia',
#                                                                'FR': 'France',
#                                                                'HU': 'France',
#                                                                'IT': 'Francia',
#                                                                'JA': 'フランス',
#                                                                'NL': 'France',
#                                                                'PT': 'França',
#                                                                'RO': 'France',
#                                                                'RU': 'Франция',
#                                                                'ZH': '法国'},
#                                                'displayName': {'AZ': 'Fransa',
#                                                                'DA': 'Frankrig',
#                                                                'DE': 'Frankreich',
#                                                                'EN': 'France',
#                                                                'ES': 'Francia',
#                                                                'FR': 'France',
#                                                                'HU': 'Franciaország',
#                                                                'IT': 'Francia',
#                                                                'JA': 'フランス',
#                                                                'NL': 'Frankrijk',
#                                                                'PT': 'França',
#                                                                'RO': 'Franța',
#                                                                'RU': 'Франция',
#                                                                'ZH': '法国'},
#                                                'displayOfficialName': {'AZ': 'Fransa',
#                                                                        'DA': 'Frankrig',
#                                                                        'DE': 'Frankreich',
#                                                                        'EN': 'France',
#                                                                        'ES': 'Francia',
#                                                                        'FR': 'France',
#                                                                        'HU': 'Franciaország',
#                                                                        'IT': 'Francia',
#                                                                        'JA': 'フランス',
#                                                                        'NL': 'Frankrijk',
#                                                                        'PT': 'França',
#                                                                        'RO': 'Franța',
#                                                                        'RU': 'Франция',
#                                                                        'ZH': '法国'},
#                                                'displayTeamCode': {'AZ': 'FRA',
#                                                                    'DA': 'FRA',
#                                                                    'DE': 'FRA',
#                                                                    'EN': 'FRA',
#                                                                    'ES': 'FRA',
#                                                                    'FR': 'FRA',
#                                                                    'HU': 'FRA',
#                                                                    'IT': 'FRA',
#                                                                    'JA': 'FRA',
#                                                                    'NL': 'FRA',
#                                                                    'PT': 'FRA',
#                                                                    'RO': 'FRA',
#                                                                    'RU': 'FRA',
#                                                                    'ZH': 'FRA'}},
#                               'typeIsNational': True,
#                               'typeTeam': 'NATIONAL'},
#                      'type': 'PLAYER'},
#   'time': {'minute': 84, 'second': 13},
#   'timestamp': '2021-06-02T20:46:39.062Z',
#   'type': 'SUBSTITUTION'},
#  {'fieldPosition': {},
#   'id': '1719a96e8f594b138a73b4a72de3aea3',
#   'matchId': '2032240',
#   'phase': 'SECOND_HALF',
#   'primaryActor': {'person': {'age': '24',
#                               'birthDate': '1997-01-03',
#                               'detailedFieldPosition': 'UNKNOWN',
#                               'fieldPosition': 'MIDFIELDER',
#                               'id': '250065196',
#                               'imageUrl': 'https://img.uefa.com/imgml/TP/players/19/2022/324x324/250065196.jpg',
#                               'internationalName': 'Joe Morrell',
#                               'translations': {'fieldPosition': {'AZ': 'Midfielder',
#                                                                  'DA': 'Midfielder',
#                                                                  'DE': 'Mittelfeldspieler',
#                                                                  'EN': 'Midfielder',
#                                                                  'ES': 'Centrocampista',
#                                                                  'FR': 'Milieu',
#                                                                  'HU': 'Midfielder',
#                                                                  'IT': 'Centrocampista',
#                                                                  'JA': 'MF',
#                                                                  'NL': 'Midfielder',
#                                                                  'PT': 'Médio',
#                                                                  'RO': 'Midfielder',
#                                                                  'RU': 'Полузащитник',
#                                                                  'ZH': '中场球员'},
#                                                'firstName': {'AZ': 'Joe',
#                                                              'DA': 'Joe',
#                                                              'DE': 'Joe',
#                                                              'EN': 'Joe',
#                                                              'ES': 'Joe',
#                                                              'FR': 'Joe',
#                                                              'HU': 'Joe',
#                                                              'IT': 'Joe',
#                                                              'JA': 'Joseff',
#                                                              'NL': 'Joe',
#                                                              'PT': 'Joe',
#                                                              'RO': 'Joe',
#                                                              'RU': 'Джо',
#                                                              'ZH': 'Joseff'},
#                                                'lastName': {'AZ': 'Morrell',
#                                                             'DA': 'Morrell',
#                                                             'DE': 'Morrell',
#                                                             'EN': 'Morrell',
#                                                             'ES': 'Morrell',
#                                                             'FR': 'Morrell',
#                                                             'HU': 'Morrell',
#                                                             'IT': 'Morrell',
#                                                             'JA': 'Morrell',
#                                                             'NL': 'Morrell',
#                                                             'PT': 'Morrell',
#                                                             'RO': 'Morrell',
#                                                             'RU': 'Моррелл',
#                                                             'ZH': 'Morrell'},
#                                                'name': {'AZ': 'Joe Morrell',
#                                                         'DA': 'Joe Morrell',
#                                                         'DE': 'Joe Morrell',
#                                                         'EN': 'Joe Morrell',
#                                                         'ES': 'Joe Morrell',
#                                                         'FR': 'Joe Morrell',
#                                                         'HU': 'Joe Morrell',
#                                                         'IT': 'Joe Morrell',
#                                                         'JA': 'Joseff Morrell',
#                                                         'NL': 'Joe Morrell',
#                                                         'PT': 'Joe Morrell',
#                                                         'RO': 'Joe Morrell',
#                                                         'RU': 'Джо Моррелл',
#                                                         'ZH': 'Joseff Morrell'},
#                                                'shortName': {'AZ': 'Morrell',
#                                                              'DA': 'Morrell',
#                                                              'DE': 'Morrell',
#                                                              'EN': 'Morrell',
#                                                              'ES': 'Morrell',
#                                                              'FR': 'Morrell',
#                                                              'HU': 'Morrell',
#                                                              'IT': 'Morrell',
#                                                              'JA': 'Morrell',
#                                                              'NL': 'Morrell',
#                                                              'PT': 'Morrell',
#                                                              'RO': 'Morrell',
#                                                              'RU': 'Моррелл',
#                                                              'ZH': 'Morrell'}}},
#                    'team': {'associationLogoUrl': 'https://img.uefa.com/imgml/uefacom/elements/logos/ma/WAL.svg',
#                             'bigLogoUrl': 'https://www.uefa.com/imgml/flags/700x700/WAL.png',
#                             'countryCode': 'WAL',
#                             'id': '144',
#                             'idProvider': 'FAME',
#                             'internationalName': 'Wales',
#                             'isPlaceHolder': False,
#                             'logoUrl': 'https://www.uefa.com/imgml/flags/70x70/WAL.png',
#                             'mediumLogoUrl': 'https://www.uefa.com/imgml/flags/240x240/WAL.png',
# ...
#                                                              'PT': 'França',
#                                                              'RO': 'Franța',
#                                                              'RU': 'Франция',
#                                                              'ZH': '法国'},
#                                              'displayOfficialName': {'AZ': 'Fransa',
#                                                                      'DA': 'Frankrig',
#                                                                      'DE': 'Frankreich',
#                                                                      'EN': 'France',
#                                                                      'ES': 'Francia',
#                                                                      'FR': 'France',
#                                                                      'HU': 'Franciaország',
#                                                                      'IT': 'Francia',
#                                                                      'JA': 'フランス',
#                                                                      'NL': 'Frankrijk',
#                                                                      'PT': 'França',
#                                                                      'RO': 'Franța',
#                                                                      'RU': 'Франция',
#                                                                      'ZH': '法国'},
#                                              'displayTeamCode': {'AZ': 'FRA',
#                                                                  'DA': 'FRA',
#                                                                  'DE': 'FRA',
#                                                                  'EN': 'FRA',
#                                                                  'ES': 'FRA',
#                                                                  'FR': 'FRA',
#                                                                  'HU': 'FRA',
#                                                                  'IT': 'FRA',
#                                                                  'JA': 'FRA',
#                                                                  'NL': 'FRA',
#                                                                  'PT': 'FRA',
#                                                                  'RO': 'FRA',
#                                                                  'RU': 'FRA',
#                                                                  'ZH': 'FRA'}},
#                             'typeIsNational': True,
#                             'typeTeam': 'NATIONAL'},
#                    'type': 'PLAYER'},
#   'subType': 'MISS',
#   'time': {'minute': 27, 'second': 36},
#   'timestamp': '2021-06-02T19:31:39.178Z',
#   'type': 'PENALTY'},
#  {'fieldPosition': {},
#   'id': 'e815b3f697324137bc1569194b1538d3',
#   'matchId': '2032240',
#   'phase': 'FIRST_HALF',
#   'primaryActor': {'person': {'age': '20',
#                               'birthDate': '2001-04-13',
#                               'detailedFieldPosition': 'UNKNOWN',
#                               'fieldPosition': 'DEFENDER',
#                               'id': '250113272',
#                               'imageUrl': 'https://img.uefa.com/imgml/TP/players/19/2022/324x324/250113272.jpg',
#                               'internationalName': 'Neco Williams',
#                               'translations': {'fieldPosition': {'AZ': 'Defender',
#                                                                  'DA': 'Defender',
#                                                                  'DE': 'Verteidiger',
#                                                                  'EN': 'Defender',
#                                                                  'ES': 'Defensa',
#                                                                  'FR': 'Défenseur',
#                                                                  'HU': 'Defender',
#                                                                  'IT': 'Difensore',
#                                                                  'JA': 'DF',
#                                                                  'NL': 'Defender',
#                                                                  'PT': 'Defesa',
#                                                                  'RO': 'Defender',
#                                                                  'RU': 'Защитник',
#                                                                  'ZH': '后卫'},
#                                                'firstName': {'AZ': 'Neco',
#                                                              'DA': 'Neco',
#                                                              'DE': 'Neco',
#                                                              'EN': 'Neco',
#                                                              'ES': 'Neco',
#                                                              'FR': 'Neco',
#                                                              'HU': 'Neco',
#                                                              'IT': 'Neco',
#                                                              'JA': 'Neco',
#                                                              'NL': 'Neco',
#                                                              'PT': 'Neco',
#                                                              'RO': 'Neco',
#                                                              'RU': 'Неко',
#                                                              'ZH': '内科'},
#                                                'lastName': {'AZ': 'Williams',
#                                                             'DA': 'Williams',
#                                                             'DE': 'Williams',
#                                                             'EN': 'Williams',
#                                                             'ES': 'Williams',
#                                                             'FR': 'Williams',
#                                                             'HU': 'Williams',
#                                                             'IT': 'Williams',
#                                                             'JA': 'Williams',
#                                                             'NL': 'Williams',
#                                                             'PT': 'Williams',
#                                                             'RO': 'Williams',
#                                                             'RU': 'Уильямс',
#                                                             'ZH': '威廉姆斯'},
#                                                'name': {'AZ': 'Neco Williams',
#                                                         'DA': 'Neco Williams',
#                                                         'DE': 'Neco Williams',
#                                                         'EN': 'Neco Williams',
#                                                         'ES': 'Neco Williams',
#                                                         'FR': 'Neco Williams',
#                                                         'HU': 'Neco Williams',
#                                                         'IT': 'Neco Williams',
#                                                         'JA': 'Neco Williams',
#                                                         'NL': 'Neco Williams',
#                                                         'PT': 'Neco Williams',
#                                                         'RO': 'Neco Williams',
#                                                         'RU': 'Неко Уильямс',
#                                                         'ZH': '内科·威廉姆斯'},
#                                                'shortName': {'AZ': 'N. '
#                                                                    'Williams',
#                                                              'DA': 'N. '
#                                                                    'Williams',
#                                                              'DE': 'N. '
#                                                                    'Williams',
#                                                              'EN': 'N. '
#                                                                    'Williams',
#                                                              'ES': 'N. '
#                                                                    'Williams',
#                                                              'FR': 'N. '
#                                                                    'Williams',
#                                                              'HU': 'N. '
#                                                                    'Williams',
#                                                              'IT': 'N. '
#                                                                    'Williams',
#                                                              'JA': 'Williams',
#                                                              'NL': 'N. '
#                                                                    'Williams',
#                                                              'PT': 'N. '
#                                                                    'Williams',
#                                                              'RO': 'N. '
#                                                                    'Williams',
#                                                              'RU': 'Н. Уильямс',
#                                                              'ZH': '威廉姆斯'}}},
#                    'team': {'associationLogoUrl': 'https://img.uefa.com/imgml/uefacom/elements/logos/ma/WAL.svg',
#                             'bigLogoUrl': 'https://www.uefa.com/imgml/flags/700x700/WAL.png',
#                             'countryCode': 'WAL',
#                             'id': '144',
#                             'idProvider': 'FAME',
#                             'internationalName': 'Wales',
#                             'isPlaceHolder': False,
#                             'logoUrl': 'https://www.uefa.com/imgml/flags/70x70/WAL.png',
#                             'mediumLogoUrl': 'https://www.uefa.com/imgml/flags/240x240/WAL.png',
#                             'teamCode': 'WAL',
#                             'teamTypeDetail': 'NATIONAL_MEN_TEAM_A',
#                             'translations': {'countryName': {'AZ': 'Wales',
#                                                              'DA': 'Wales',
#                                                              'DE': 'Wales',
#                                                              'EN': 'Wales',
#                                                              'ES': 'Gales',
#                                                              'FR': 'Pays de '
#                                                                    'Galles',
#                                                              'HU': 'Wales',
#                                                              'IT': 'Galles',
#                                                              'JA': 'ウェールズ',
#                                                              'NL': 'Wales',
#                                                              'PT': 'País de '
#                                                                    'Gales',
#                                                              'RO': 'Wales',
#                                                              'RU': 'Уэльс',
#                                                              'ZH': '威尔士'},
#                                              'displayName': {'AZ': 'Uels',
#                                                              'DA': 'Wales',
#                                                              'DE': 'Wales',
#                                                              'EN': 'Wales',
#                                                              'ES': 'Gales',
#                                                              'FR': 'Pays de '
#                                                                    'Galles',
#                                                              'HU': 'Wales',
#                                                              'IT': 'Galles',
#                                                              'JA': 'ウェールズ',
#                                                              'NL': 'Wales',
#                                                              'PT': 'País de '
#                                                                    'Gales',
#                                                              'RO': 'Țara '
#                                                                    'Galilor',
#                                                              'RU': 'Уэльс',
#                                                              'ZH': '威尔士'},
#                                              'displayOfficialName': {'AZ': 'Uels',
#                                                                      'DA': 'Wales',
#                                                                      'DE': 'Wales',
#                                                                      'EN': 'Wales',
#                                                                      'ES': 'Gales',
#                                                                      'FR': 'Pays '
#                                                                            'de '
#                                                                            'Galles',
#                                                                      'HU': 'Wales',
#                                                                      'IT': 'Galles',
#                                                                      'JA': 'ウェールズ',
#                                                                      'NL': 'Wales',
#                                                                      'PT': 'País '
#                                                                            'de '
#                                                                            'Gales',
#                                                                      'RO': 'Țara '
#                                                                            'Galilor',
#                                                                      'RU': 'Уэльс',
#                                                                      'ZH': '威尔士'},
#                                              'displayTeamCode': {'AZ': 'WAL',
#                                                                  'DA': 'WAL',
#                                                                  'DE': 'WAL',
#                                                                  'EN': 'WAL',
#                                                                  'ES': 'WAL',
#                                                                  'FR': 'WAL',
#                                                                  'HU': 'WAL',
#                                                                  'IT': 'WAL',
#                                                                  'JA': 'WAL',
#                                                                  'NL': 'WAL',
#                                                                  'PT': 'WAL',
#                                                                  'RO': 'WAL',
#                                                                  'RU': 'WAL',
#                                                                  'ZH': 'WAL'}},
#                             'typeIsNational': True,
#                             'typeTeam': 'NATIONAL'},
#                    'type': 'PLAYER'},
#   'time': {'minute': 26, 'second': 46},
#   'timestamp': '2021-06-02T19:30:49.255Z',
#   'type': 'RED_CARD'}]

# %%
#print(lineup['lineupStatus'])
#print(lineup['matchId'])

print(lineup['awayTeam']['shirtColor'])
print(lineup['homeTeam']['shirtColor'])


# for p in lineup['awayTeam']['field']:
for p in lineup['homeTeam']['field']:
    print(p['fieldCoordinate'])
    print(p['type'])  # can be : PLAYER, CAPTAIN, GOALKEEPER, GOALKEEPER_CAPTAIN
    print(p['player']['internationalName'], f"#{p['jerseyNumber']}", "\t",  p['player']['id'], )
    print()

'''
for p in lineup['homeTeam']['bench']:
    #print(p['type'])  # can be : PLAYER, CAPTAIN, GOALKEEPER, GOALKEEPER_CAPTAIN
    #print(p['player']['internationalName'], f"#{p['jerseyNumber']}", "\t",  p['player']['id'], )
    pprint(p)
'''
# Out:
# #FF0000
# #0000A0
# {'x': 500, 'y': 50}
# GOALKEEPER_CAPTAIN
# Hugo Lloris #1 	 93846
#
# {'x': 200, 'y': 250}
# PLAYER
# Benjamin Pavard #2 	 250081921
#
# {'x': 600, 'y': 250}
# PLAYER
# Presnel Kimpembe #3 	 250064583
#
# {'x': 400, 'y': 250}
# PLAYER
# Raphaël Varane #4 	 250025891
#
# {'x': 300, 'y': 500}
# PLAYER
# Paul Pogba #6 	 250015808
#
# {'x': 300, 'y': 800}
# PLAYER
# Antoine Griezmann #7 	 250019498
#
# {'x': 700, 'y': 800}
# PLAYER
# Kylian Mbappé #10 	 250076574
#
# {'x': 500, 'y': 500}
# PLAYER
# Corentin Tolisso #12 	 250054829
#
# {'x': 700, 'y': 500}
# PLAYER
# Adrien Rabiot #14 	 250053905
#
# {'x': 500, 'y': 800}
# PLAYER
# Karim Benzema #19 	 93321
#
# {'x': 800, 'y': 250}
# PLAYER
# Lucas Hernández #21 	 250063803
# '\nfor p in lineup[\'homeTeam\'][\'bench\']:\n    #print(p[\'type\'])  # can be : PLAYER, CAPTAIN, GOALKEEPER, GOALKEEPER_CAPTAIN\n    #print(p[\'player\'][\'internationalName\'], f"#{p[\'jerseyNumber\']}", "\t",  p[\'player\'][\'id\'], )\n    pprint(p)\n'
